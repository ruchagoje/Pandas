# %% [markdown]
# Mastering advanced indexing and slicing in Pandas DataFrames

# %%
# Write a Pandas program to select rows where the value in the 'A' column is greater than 4 and display only the first five matching rows.
import pandas as pd


data = {'A': [1, 6, 8, 3, 7, 9, 2, 10, 5, 4],
        'B': [5, 2, 9, 4, 1, 3, 6, 8, 7, 0]}
df = pd.DataFrame(data)

result = df[df['A'] > 4].head(5)

print(result)
# Out:
#     A  B
# 1   6  2
# 2   8  9
# 4   7  1
# 5   9  3
# 7  10  8

# %%
# Write a Pandas program to select rows with 'A' > 4 and then compute the mean of the remaining columns.

import pandas as pd
import numpy as np

df = pd.DataFrame({'A': [3,  5, 2, 6, 4],
        'B': [10, 8, 12, 7, 9],
        'C': [15, 13, 16, 11, 14]})



result = df[df['A']>4].drop('A', axis=1).mean()
print(result)
# Out:
# B     7.5
# C    12.0
# dtype: float64

# %%
# Write a Pandas program to filter rows from a DataFrame where column 'A' exceeds 4 and then sort the results by another column.

import pandas as pd
import numpy as np

df = pd.DataFrame({'A': [3,  5, 2, 6, 4],
        'B': [10, 8, 12, 7, 9],
        'C': [15, 13, 16, 11, 14]})



result = df[df['A']>4].sort_values(by='B', ascending=True)
print(result)
# Out:
#    A  B   C
# 3  6  7  11
# 1  5  8  13

# %%
# Write a Pandas program to extract rows where 'A' is greater than 4 and create a new DataFrame with only these rows.

df = pd.DataFrame({'A': [3,  5, 2, 6, 4],
        'B': [10, 8, 12, 7, 9],
        'C': [15, 13, 16, 11, 14]})



result = df[df['A']>4]
result
# Out:
#    A  B   C
# 1  5  8  13
# 3  6  7  11
