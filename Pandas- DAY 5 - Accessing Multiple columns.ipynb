# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("/content/sample_data/liver.csv")
df1
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...        ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6       0.37
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2       1.10
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2       1.00
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4       1.00
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4       1.50
#
#      Selector
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 578         2
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'A/G Ratio', 'Selector'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'A/G Ratio', 'Selector'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age            int64
# Gender        object
# TB           float64
# DB           float64
# Alkphos        int64
# Sgpt           int64
# Sgot           int64
# TP           float64
# ALB          float64
# A/G Ratio    float64
# Selector       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        583 non-null    int64
#  1   Gender     583 non-null    object
#  2   TB         583 non-null    float64
#  3   DB         583 non-null    float64
#  4   Alkphos    583 non-null    int64
#  5   Sgpt       583 non-null    int64
#  6   Sgot       583 non-null    int64
#  7   TP         583 non-null    float64
#  8   ALB        583 non-null    float64
#  9   A/G Ratio  579 non-null    float64
#  10  Selector   583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.isnull().sum()
# Out:
# Age          0
# Gender       0
# TB           0
# DB           0
# Alkphos      0
# Sgpt         0
# Sgot         0
# TP           0
# ALB          0
# A/G Ratio    4
# Selector     0
# dtype: int64

# %%
df[['TB', 'DB']]
# Out:
#        TB   DB
# 0     0.7  0.1
# 1    10.9  5.5
# 2     7.3  4.1
# 3     1.0  0.4
# 4     3.9  2.0
# ..    ...  ...
# 578   0.5  0.1
# 579   0.6  0.1
# 580   0.8  0.2
# 581   1.3  0.5
# 582   1.0  0.3
#
# [583 rows x 2 columns]

# %% [markdown]
# drop a row

# %%
df = df.drop(0, axis=0)
df
# Out:
#      Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 1     62   Male  10.9  5.5      699    64   100  7.5  3.2       0.74         1
# 2     62   Male   7.3  4.1      490    60    68  7.0  3.3       0.89         1
# 3     58   Male   1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4     72   Male   3.9  2.0      195    27    59  7.3  2.4       0.40         1
# 5     46   Male   1.8  0.7      208    19    14  7.6  4.4       1.30         1
# ..   ...    ...   ...  ...      ...   ...   ...  ...  ...        ...       ...
# 578   60   Male   0.5  0.1      500    20    34  5.9  1.6       0.37         2
# 579   40   Male   0.6  0.1       98    35    31  6.0  3.2       1.10         1
# 580   52   Male   0.8  0.2      245    48    49  6.4  3.2       1.00         1
# 581   31   Male   1.3  0.5      184    29    32  6.8  3.4       1.00         1
# 582   38   Male   1.0  0.3      216    21    24  7.3  4.4       1.50         2
#
# [582 rows x 11 columns]

# %% [markdown]
# Drop multiple rows

# %%
df1 = df.drop(index=[0,1])

df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-28-4282760259.py in <cell line: 0>()
# ----> 1 df1 = df.drop(index=[0,1])
#       2
#       3 df1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
 df1['Gender'] == "Male"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 578     True
# 579     True
# 580     True
# 581     True
# 582     True
# Name: Gender, Length: 583, dtype: bool

# %%
df[df['Gender'] == 'Male']
# Out:
#      Age Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 3     58   Male  1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4     72   Male  3.9  2.0      195    27    59  7.3  2.4       0.40         1
# 5     46   Male  1.8  0.7      208    19    14  7.6  4.4       1.30         1
# 8     17   Male  0.9  0.3      202    22    19  7.4  4.1       1.20         2
# 9     55   Male  0.7  0.2      290    53    58  6.8  3.4       1.00         1
# ..   ...    ...  ...  ...      ...   ...   ...  ...  ...        ...       ...
# 578   60   Male  0.5  0.1      500    20    34  5.9  1.6       0.37         2
# 579   40   Male  0.6  0.1       98    35    31  6.0  3.2       1.10         1
# 580   52   Male  0.8  0.2      245    48    49  6.4  3.2       1.00         1
# 581   31   Male  1.3  0.5      184    29    32  6.8  3.4       1.00         1
# 582   38   Male  1.0  0.3      216    21    24  7.3  4.4       1.50         2
#
# [439 rows x 11 columns]

# %%
male_data = df[df['Gender']== 'Male']
male_data
# Out:
#      Age Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 3     58   Male  1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4     72   Male  3.9  2.0      195    27    59  7.3  2.4       0.40         1
# 5     46   Male  1.8  0.7      208    19    14  7.6  4.4       1.30         1
# 8     17   Male  0.9  0.3      202    22    19  7.4  4.1       1.20         2
# 9     55   Male  0.7  0.2      290    53    58  6.8  3.4       1.00         1
# ..   ...    ...  ...  ...      ...   ...   ...  ...  ...        ...       ...
# 578   60   Male  0.5  0.1      500    20    34  5.9  1.6       0.37         2
# 579   40   Male  0.6  0.1       98    35    31  6.0  3.2       1.10         1
# 580   52   Male  0.8  0.2      245    48    49  6.4  3.2       1.00         1
# 581   31   Male  1.3  0.5      184    29    32  6.8  3.4       1.00         1
# 582   38   Male  1.0  0.3      216    21    24  7.3  4.4       1.50         2
#
# [439 rows x 11 columns]

# %%
df[df['Age'] >= 50]
# Out:
#      Age  Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 3     58    Male  1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4     72    Male  3.9  2.0      195    27    59  7.3  2.4       0.40         1
# 9     55    Male  0.7  0.2      290    53    58  6.8  3.4       1.00         1
# 10    57    Male  0.6  0.1      210    51    59  5.9  2.7       0.80         1
# 11    72    Male  2.7  1.3      260    31    56  7.4  3.0       0.60         1
# ..   ...     ...  ...  ...      ...   ...   ...  ...  ...        ...       ...
# 566   50  Female  1.0  0.3      191    22    31  7.8  4.0       1.00         2
# 567   52    Male  2.7  1.4      251    20    40  6.0  1.7       0.39         1
# 571   90    Male  1.1  0.3      215    46   134  6.9  3.0       0.70         1
# 578   60    Male  0.5  0.1      500    20    34  5.9  1.6       0.37         2
# 580   52    Male  0.8  0.2      245    48    49  6.4  3.2       1.00         1
#
# [227 rows x 11 columns]

# %%
filter1 = df[(df['Age']==65) | (df['Gender']== 'Female')]
filter1
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 6     26  Female   0.9   0.2      154    16    12  7.0  3.5       1.00
# 7     29  Female   0.9   0.3      202    14    11  6.7  3.6       1.10
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1       1.00
# 18    40  Female   0.9   0.3      293   232   245  6.8  3.1       0.80
# 19    40  Female   0.9   0.3      293   232   245  6.8  3.1       0.80
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...        ...
# 547   50  Female  27.7  10.8      380    39   348  7.1  2.3       0.40
# 549   40  Female   2.1   1.0      768    74   141  7.8  4.9       1.60
# 564   38  Female   0.6   0.1      165    22    34  5.9  2.9       0.90
# 566   50  Female   1.0   0.3      191    22    31  7.8  4.0       1.00
# 568   20  Female  16.7   8.4      200    91   101  6.9  3.5       1.02
#
#      Selector
# 6           1
# 7           1
# 13          1
# 18          1
# 19          1
# ..        ...
# ...

# %%
filter2 = df[(df['Selector'] ==1 ) & (df.Age >= 70)]
filter2
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40
# 11    72    Male   2.7  1.3      260    31    56  7.4  3.0       0.60
# 13    74  Female   1.1  0.4      214    22    30  8.1  4.1       1.00
# 71    75  Female   0.8  0.2      188    20    29  4.4  1.8       0.60
# 72    75  Female   0.8  0.2      205    27    24  4.4  2.0       0.80
# 95    75    Male   0.9  0.2      282    25    23  4.4  2.2       1.00
# 113   74    Male   0.6  0.1      272    24    98  5.0  2.0       0.60
# 157   72    Male   0.7  0.1      196    20    35  5.8  2.0       0.50
# 158   72    Male   0.7  0.1      196    20    35  5.8  2.0       0.50
# 170   72    Male   1.7  0.8      200    28    37  6.2  3.0       0.93
# 177   75    Male  14.8  9.0     1020    71    42  5.3  2.2       0.70
# 178   75    Male  10.6  5.0      562    37    29  5.1  1.8       0.50
# ...

# %%
filter3 = df[(df['Gender'] == 'Female') | (df['Age'] >= 35) | (df['DB'] <= 6)]
filter3
# Out:
#      Age  Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 3     58    Male  1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4     72    Male  3.9  2.0      195    27    59  7.3  2.4       0.40         1
# 5     46    Male  1.8  0.7      208    19    14  7.6  4.4       1.30         1
# 6     26  Female  0.9  0.2      154    16    12  7.0  3.5       1.00         1
# 7     29  Female  0.9  0.3      202    14    11  6.7  3.6       1.10         1
# ..   ...     ...  ...  ...      ...   ...   ...  ...  ...        ...       ...
# 578   60    Male  0.5  0.1      500    20    34  5.9  1.6       0.37         2
# 579   40    Male  0.6  0.1       98    35    31  6.0  3.2       1.10         1
# 580   52    Male  0.8  0.2      245    48    49  6.4  3.2       1.00         1
# 581   31    Male  1.3  0.5      184    29    32  6.8  3.4       1.00         1
# 582   38    Male  1.0  0.3      216    21    24  7.3  4.4       1.50         2
#
# [566 rows x 11 columns]

# %% [markdown]
# iloc

# %%
#get the 1st row
df.iloc[0]
# Out:
# Age            58
# Gender       Male
# TB            1.0
# DB            0.4
# Alkphos       182
# Sgpt           14
# Sgot           20
# TP            6.8
# ALB           3.4
# A/G Ratio     1.0
# Selector        1
# Name: 3, dtype: object

# %%
df.iloc[-1]
# Out:
# Age            38
# Gender       Male
# TB            1.0
# DB            0.3
# Alkphos       216
# Sgpt           21
# Sgot           24
# TP            7.3
# ALB           4.4
# A/G Ratio     1.5
# Selector        2
# Name: 582, dtype: object

# %%
df.iloc[[3, 13, 20]]
# Out:
#     Age  Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 6    26  Female  0.9  0.2      154    16    12  7.0  3.5        1.0         1
# 16   38    Male  1.8  0.8      342   168   441  7.6  4.4        1.3         1
# 23   40    Male  1.9  1.0      231    16    55  4.3  1.6        0.6         1

# %%
# displaying multiple specicified columns and rows
df.iloc[[3, 13, 20], [1,4]]
# Out:
#     Gender  Alkphos
# 6   Female      154
# 16    Male      342
# 23    Male      231

# %%
df.iloc[1,2]
# Out:
# np.float64(3.9)

# %%
#displaying specific colum of range of rows
df.iloc[: , [4,5]]
# Out:
#      Alkphos  Sgpt
# 3        182    14
# 4        195    27
# 5        208    19
# 6        154    16
# 7        202    14
# ..       ...   ...
# 578      500    20
# 579       98    35
# 580      245    48
# 581      184    29
# 582      216    21
#
# [580 rows x 2 columns]

# %% [markdown]
# loc

# %%
#get the 17th row
print(df.loc[16])
# Out:
# Age            38
# Gender       Male
# TB            1.8
# DB            0.8
# Alkphos       342
# Sgpt          168
# Sgot          441
# TP            7.6
# ALB           4.4
# A/G Ratio     1.3
# Selector        1
# Name: 16, dtype: object

# %%
print(df.loc[-8])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -8 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-55-1146810294.py in <cell line: 0>()
# ----> 1 print(df.loc[-8])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# ...

# %%
df.loc[51:55]
# Out:
#     Age  Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 51   34  Female  0.6  0.1      161    15    19  6.6  3.4        1.0         1
# 52   38    Male  3.1  1.6      253    80   406  6.8  3.9        1.3         1
# 53   38    Male  1.1  0.3      198    86   150  6.3  3.5        1.2         1
# 54   42    Male  8.9  4.5      272    31    61  5.8  2.0        0.5         1
# 55   42    Male  8.9  4.5      272    31    61  5.8  2.0        0.5         1

# %%
df.loc[[5,6], 'TB': 'DB']
# Out:
#     TB   DB
# 5  1.8  0.7
# 6  0.9  0.2

# %% [markdown]
# diff between loc and iloc

# %%
df.loc[5, 'Age']
# Out:
# np.int64(46)

# %%
df.iloc[5, 0]
# Out:
# np.int64(17)

# %%
df.iloc[[4,5], 0:4]
# Out:
#    Age  Gender   TB   DB
# 7   29  Female  0.9  0.3
# 8   17    Male  0.9  0.3

# %%
df.loc[[4,5], 'Age': 'DB']
# Out:
#    Age Gender   TB   DB
# 4   72   Male  3.9  2.0
# 5   46   Male  1.8  0.7

# %% [markdown]
# SetIndex

# %%
l1 = df.set_index("TB")
l1
# Out:
#      Age  Gender   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# TB
# 1.0   58    Male  0.4      182    14    20  6.8  3.4       1.00         1
# 3.9   72    Male  2.0      195    27    59  7.3  2.4       0.40         1
# 1.8   46    Male  0.7      208    19    14  7.6  4.4       1.30         1
# 0.9   26  Female  0.2      154    16    12  7.0  3.5       1.00         1
# 0.9   29  Female  0.3      202    14    11  6.7  3.6       1.10         1
# ..   ...     ...  ...      ...   ...   ...  ...  ...        ...       ...
# 0.5   60    Male  0.1      500    20    34  5.9  1.6       0.37         2
# 0.6   40    Male  0.1       98    35    31  6.0  3.2       1.10         1
# 0.8   52    Male  0.2      245    48    49  6.4  3.2       1.00         1
# 1.3   31    Male  0.5      184    29    32  6.8  3.4       1.00         1
# 1.0   38    Male  0.3      216    21    24  7.3  4.4       1.50         2
#
# [580 rows x 10 columns]

# %%
l1.loc[0.5]
# Out:
#      Age  Gender   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# TB
# 0.5   63    Male  0.1      170    21    28  5.5  2.5       0.80         1
# 0.5   42  Female  0.1      162   155   108  8.1  4.0       0.90         1
# 0.5   17  Female  0.1      206    28    21  7.1  4.5       1.70         2
# 0.5    7    Male  0.1      352    28    51  7.9  4.2       1.10         2
# 0.5   60    Male  0.1      500    20    34  5.9  1.6       0.37         2

# %%
l1.loc[1.0, 'DB': 'ALB']
# Out:
#       DB  Alkphos  Sgpt  Sgot   TP  ALB
# TB
# 1.0  0.4      182    14    20  6.8  3.4
# 1.0  0.3      187    19    23  5.2  2.9
# 1.0  0.3      208    17    15  7.0  3.6
# 1.0  0.5      158    37    43  7.2  3.6
# 1.0  0.5      158    37    43  7.2  3.6
# 1.0  0.3       75    25    26  5.1  2.9
# 1.0  0.3      142    27    21  6.4  3.5
# 1.0  0.3      202    26    13  5.3  2.6
# 1.0  1.4      144    18    14  8.3  4.2
# 1.0  0.5      239    16    39  7.5  3.7
# 1.0  0.3      250    48    44  8.6  4.3
# 1.0  0.3      310    37    56  5.9  2.5
# 1.0  0.3      175    30    32  6.4  3.4
# 1.0  0.3      152    28    70  6.3  3.1
# 1.0  0.2      205   137   145  6.0  3.0
# 1.0  0.2      719   157   108  7.2  3.7
# 1.0  0.3      163    48    71  7.1  3.7
# 1.0  0.3      212    41    80  6.2  3.1
# 1.0  0.3       90    18   108  6.8  3.1
# 1.0  0.3      190    30    54  5.3  2.1
# 1.0  0.3      154    38    21  6.8  3.9
# 1.0  0.3      180    56   111  6.8  3.9
# ...

# %%
l1.reset_index()
# Out:
#       TB  Age  Gender   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 0    1.0   58    Male  0.4      182    14    20  6.8  3.4       1.00         1
# 1    3.9   72    Male  2.0      195    27    59  7.3  2.4       0.40         1
# 2    1.8   46    Male  0.7      208    19    14  7.6  4.4       1.30         1
# 3    0.9   26  Female  0.2      154    16    12  7.0  3.5       1.00         1
# 4    0.9   29  Female  0.3      202    14    11  6.7  3.6       1.10         1
# ..   ...  ...     ...  ...      ...   ...   ...  ...  ...        ...       ...
# 575  0.5   60    Male  0.1      500    20    34  5.9  1.6       0.37         2
# 576  0.6   40    Male  0.1       98    35    31  6.0  3.2       1.10         1
# 577  0.8   52    Male  0.2      245    48    49  6.4  3.2       1.00         1
# 578  1.3   31    Male  0.5      184    29    32  6.8  3.4       1.00         1
# 579  1.0   38    Male  0.3      216    21    24  7.3  4.4       1.50         2
#
# [580 rows x 11 columns]

# %%
df1= df.loc[df['DB'] > 3.7, ['Age', 'DB', 'Selector']]
df1['Selector'].value_counts()
# Out:
# Selector
# 1    61
# Name: count, dtype: int64

# %%
df.loc[df['TB'] < 0.5, 'Gender': 'Selector']
# Out:
#     Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 425   Male  0.4  0.1      100    59   126  4.3  2.5        1.4         1

# %%
df.loc[(df['Sgpt'] > 400) & (df['Sgpt'] <= 420), "TB": 'Alkphos']
# Out:
#      TB   DB  Alkphos
# 43  2.6  1.2      415
# 90  5.7  2.8      214
# 91  6.8  3.2      308
# 92  8.6  4.0      298

# %% [markdown]
# GroupBy

# %%
male = df[df['Gender'] == 'Male']

# %%
female = df[df['Gender'] == 'Female']

# %%
male["TB"].mean()
# Out:
# np.float64(3.5881548974943054)

# %%
female['TB'].mean()
# Out:
# np.float64(2.3340425531914892)

# %%
df.groupby('Gender')['TB'].mean()
# Out:
# Gender
# Female    2.334043
# Male      3.588155
# Name: TB, dtype: float64

# %% [markdown]
# CrossTab

# %%
male = df[df['Gender']== 'Male']
male['Selector'].value_counts()
# Out:
# Selector
# 1    322
# 2    117
# Name: count, dtype: int64

# %%
female= df[df['Gender'] == "Female"]
female['Selector' ].value_counts()
# Out:
# Selector
# 1    91
# 2    50
# Name: count, dtype: int64

# %%
pd.crosstab(df['Gender'], df['Selector'], margins=True)
# Out:
# Selector    1    2  All
# Gender
# Female     91   50  141
# Male      322  117  439
# All       413  167  580
